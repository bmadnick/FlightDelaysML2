# %% [markdown]
# # Imports

# %%
from datetime import datetime

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
print(tf.__version__)
# Out:
# 2.9.1

# %% [markdown]
# # Feature Engineering

# %%
#read in the data
df = pd.read_csv('TSACheckinTS.csv')
df.head(5)
# Out:
#    Unnamed: 0        Date  Checkins
# 0          99  2019-01-01   2202111
# 1          98  2019-01-02   2150571
# 2          97  2019-01-03   1975947
# 3          96  2019-01-04   2229391
# 4          95  2019-01-05   2044043

# %% [markdown]
# Fast Fourier Transform

# %%
fft = tf.signal.rfft(df['Checkins'])
f_per_dataset = np.arange(0,len(fft))

n_sample = len(df['Checkins'])
weeks_per_dataset = n_sample / 7
f_per_week = f_per_dataset / weeks_per_dataset

plt.step(f_per_week, np.abs(fft))
plt.xscale('log')
plt.xticks([1, 7], ['1/week', '1/day'])
plt.xlabel('Frequency')
plt.tight_layout()
plt.show()

# %%
df.Date.describe()
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# /var/folders/wz/44mfxs_n0fs5bcb4z1rph6dm0000gn/T/ipykernel_33660/1102791421.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.Date.describe()

# %%
#create the trignonometric values for the data
timestamp_s = df.Date.map(datetime.timestamp)

day = 24 * 60 * 60

df['day_sin'] = (np.sin(timestamp_s * (2*np.pi/day))).values
df['day_cos'] = (np.cos(timestamp_s * (2*np.pi/day))).values

df.head()
# Out:
#    Unnamed: 0       Date  Checkins   day_sin   day_cos
# 0          99 2019-01-01   2202111  0.965926  0.258819
# 1          98 2019-01-02   2150571  0.965926  0.258819
# 2          97 2019-01-03   1975947  0.965926  0.258819
# 3          96 2019-01-04   2229391  0.965926  0.258819
# 4          95 2019-01-05   2044043  0.965926  0.258819

# %% [markdown]
# # Splitting data

# %%
df = df.drop(['Date'], axis=1)
df.head()
# Out:
#    Unnamed: 0  Checkins   day_sin   day_cos
# 0          99   2202111  0.965926  0.258819
# 1          98   2150571  0.965926  0.258819
# 2          97   1975947  0.965926  0.258819
# 3          96   2229391  0.965926  0.258819
# 4          95   2044043  0.965926  0.258819

# %%
n = len(df)

# Split 70:20:10 (train:validation:test)
train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):int(n*0.9)]
test_df = df[int(n*0.9):]

train_df.shape, val_df.shape, test_df.shape
# Out:
# ((1089, 4), (311, 4), (156, 4))

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1089 entries, 0 to 1088
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1089 non-null   int64
#  1   Checkins    1089 non-null   int64
#  2   day_sin     1089 non-null   float64
#  3   day_cos     1089 non-null   float64
# dtypes: float64(2), int64(2)
# memory usage: 34.2 KB

# %%
scaler = MinMaxScaler()
scaler.fit(train_df)

train_df[train_df.columns] = scaler.transform(train_df[train_df.columns])
val_df[val_df.columns] = scaler.transform(val_df[val_df.columns])
test_df[test_df.columns] = scaler.transform(test_df[test_df.columns])
# Out:
# /var/folders/wz/44mfxs_n0fs5bcb4z1rph6dm0000gn/T/ipykernel_33660/1038120894.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[train_df.columns] = scaler.transform(train_df[train_df.columns])
# /var/folders/wz/44mfxs_n0fs5bcb4z1rph6dm0000gn/T/ipykernel_33660/1038120894.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df[val_df.columns] = scaler.transform(val_df[val_df.columns])
# /var/folders/wz/44mfxs_n0fs5bcb4z1rph6dm0000gn/T/ipykernel_33660/1038120894.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[test_df.columns] = scaler.transform(test_df[test_df.columns])

# %% [markdown]
# # Deep Learning Models

# %% [markdown]
# ## `DataWindow` class

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        self.train_df = train_df 
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
        
    def split_to_input_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                        [labels[:,:,self.column_indices[name]] for name in self.label_columns], axis=-1
                    )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        return inputs, labels

    def plot(self, model=None, plot_col='Checkins', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3,1,n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                    label='Inputs', marker = '.', zorder=-10)
            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (D)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype = np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(data=data,
                                                                 targets=None,
                                                                 sequence_length=self.total_window_size,
                                                                 sequence_stride=1,
                                                                 shuffle=True,
                                                                 batch_size=32,
                                                                 )
        ds = ds.map(self.split_to_input_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## Baseline Models

# %%
multi_window = DataWindow(input_width=30, label_width=30, shift=30, label_columns=['Checkins'])

# %% [markdown]
# ### Repeat last value

# %%
class MultiStepLastBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return tf.tile(inputs[:, -1:, :], [1, 30, 1])
        return tf.tile(inputs[:, -1:, self.label_index:], [1, 30, 1])

# %%
baseline_last = MultiStepLastBaseline(label_index = column_indices['Checkins'])
baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance = {}
performance = {}

val_performance['Baseline - Last'] = baseline_last.evaluate(multi_window.val)
performance['Baseline - Last'] = baseline_last.evaluate(multi_window.test, verbose = 0)
# Out:
# 8/8 [==============================] - 1s 2ms/step - loss: 0.2116 - mean_absolute_error: 0.3597

# %%
multi_window.plot(baseline_last)
plt.show()

# %% [markdown]
# ### Repeat Last Day

# %%
class RepeatBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        return inputs[:, :, self.label_index:]

# %%
baseline_repeat = RepeatBaseline(label_index=column_indices['Checkins'])

baseline_repeat.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.val)
performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.test, verbose=0)
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2137 - mean_absolute_error: 0.3686

# %%
multi_window.plot(baseline_repeat)
plt.show()

# %% [markdown]
# With the repeat last day we can see that there is almost a monthly seasonality with checkins.  This is most noticeable with the third plot above.

# %% [markdown]
# ### Linear Model

# %%
label_index = column_indices['Checkins']
num_features = train_df.shape[1]

linear = Sequential([Dense(1, kernel_initializer=tf.initializers.zeros)])

history = compile_and_fit(linear, multi_window)

val_performance['Linear'] = linear.evaluate(multi_window.val)
performance['Linear'] = linear.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 1s 9ms/step - loss: 0.3099 - mean_absolute_error: 0.4874 - val_loss: 0.4058 - val_mean_absolute_error: 0.6328
# Epoch 2/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2236 - mean_absolute_error: 0.4038 - val_loss: 0.2944 - val_mean_absolute_error: 0.5377
# Epoch 3/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1612 - mean_absolute_error: 0.3377 - val_loss: 0.2110 - val_mean_absolute_error: 0.4535
# Epoch 4/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1188 - mean_absolute_error: 0.2926 - val_loss: 0.1517 - val_mean_absolute_error: 0.3822
# Epoch 5/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0912 - mean_absolute_error: 0.2621 - val_loss: 0.1094 - val_mean_absolute_error: 0.3218
# Epoch 6/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0746 - mean_absolute_error: 0.2409 - val_loss: 0.0821 - val_mean_absolute_error: 0.2757
# Epoch 7/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0649 - mean_absolute_error: 0.2253 - val_loss: 0.0631 - val_mean_absolute_error: 0.2384
# Epoch 8/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0592 - mean_absolute_error: 0.2146 - val_loss: 0.0509 - val_mean_absolute_error: 0.2110
# Epoch 9/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0561 - mean_absolute_error: 0.2073 - val_loss: 0.0431 - val_mean_absolute_error: 0.1914
# Epoch 10/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0542 - mean_absolute_error: 0.2024 - val_loss: 0.0378 - val_mean_absolute_error: 0.1770
# Epoch 11/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0529 - mean_absolute_error: 0.1988 - val_loss: 0.0347 - val_mean_absolute_error: 0.1679
# Epoch 12/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0519 - mean_absolute_error: 0.1959 - val_loss: 0.0324 - val_mean_absolute_error: 0.1611
# Epoch 13/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0510 - mean_absolute_error: 0.1933 - val_loss: 0.0306 - val_mean_absolute_error: 0.1553
# Epoch 14/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0502 - mean_absolute_error: 0.1915 - val_loss: 0.0301 - val_mean_absolute_error: 0.1538
# Epoch 15/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0494 - mean_absolute_error: 0.1897 - val_loss: 0.0293 - val_mean_absolute_error: 0.1516
# Epoch 16/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0485 - mean_absolute_error: 0.1879 - val_loss: 0.0290 - val_mean_absolute_error: 0.1504
# Epoch 17/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0477 - mean_absolute_error: 0.1862 - val_loss: 0.0283 - val_mean_absolute_error: 0.1482
# Epoch 18/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0470 - mean_absolute_error: 0.1843 - val_loss: 0.0275 - val_mean_absolute_error: 0.1455
# Epoch 19/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0461 - mean_absolute_error: 0.1823 - val_loss: 0.0267 - val_mean_absolute_error: 0.1428
# Epoch 20/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0454 - mean_absolute_error: 0.1804 - val_loss: 0.0260 - val_mean_absolute_error: 0.1406
# Epoch 21/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0446 - mean_absolute_error: 0.1787 - val_loss: 0.0260 - val_mean_absolute_error: 0.1406
# Epoch 22/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0438 - mean_absolute_error: 0.1771 - val_loss: 0.0261 - val_mean_absolute_error: 0.1406
# Epoch 23/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0431 - mean_absolute_error: 0.1752 - val_loss: 0.0254 - val_mean_absolute_error: 0.1381
# Epoch 24/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0423 - mean_absolute_error: 0.1734 - val_loss: 0.0247 - val_mean_absolute_error: 0.1357
# Epoch 25/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0416 - mean_absolute_error: 0.1716 - val_loss: 0.0244 - val_mean_absolute_error: 0.1343
# Epoch 26/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0408 - mean_absolute_error: 0.1700 - val_loss: 0.0243 - val_mean_absolute_error: 0.1339
# Epoch 27/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0401 - mean_absolute_error: 0.1683 - val_loss: 0.0241 - val_mean_absolute_error: 0.1333
# Epoch 28/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0394 - mean_absolute_error: 0.1666 - val_loss: 0.0238 - val_mean_absolute_error: 0.1318
# Epoch 29/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0388 - mean_absolute_error: 0.1649 - val_loss: 0.0235 - val_mean_absolute_error: 0.1306
# Epoch 30/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0381 - mean_absolute_error: 0.1631 - val_loss: 0.0227 - val_mean_absolute_error: 0.1275
# Epoch 31/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0375 - mean_absolute_error: 0.1614 - val_loss: 0.0228 - val_mean_absolute_error: 0.1279
# Epoch 32/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0368 - mean_absolute_error: 0.1598 - val_loss: 0.0224 - val_mean_absolute_error: 0.1261
# Epoch 33/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0362 - mean_absolute_error: 0.1580 - val_loss: 0.0219 - val_mean_absolute_error: 0.1243
# Epoch 34/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0356 - mean_absolute_error: 0.1563 - val_loss: 0.0213 - val_mean_absolute_error: 0.1222
# Epoch 35/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0350 - mean_absolute_error: 0.1549 - val_loss: 0.0213 - val_mean_absolute_error: 0.1219
# Epoch 36/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0345 - mean_absolute_error: 0.1533 - val_loss: 0.0209 - val_mean_absolute_error: 0.1205
# Epoch 37/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0339 - mean_absolute_error: 0.1518 - val_loss: 0.0207 - val_mean_absolute_error: 0.1196
# Epoch 38/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0334 - mean_absolute_error: 0.1502 - val_loss: 0.0202 - val_mean_absolute_error: 0.1174
# Epoch 39/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0329 - mean_absolute_error: 0.1488 - val_loss: 0.0201 - val_mean_absolute_error: 0.1169
# Epoch 40/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0324 - mean_absolute_error: 0.1474 - val_loss: 0.0200 - val_mean_absolute_error: 0.1164
# Epoch 41/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0320 - mean_absolute_error: 0.1460 - val_loss: 0.0200 - val_mean_absolute_error: 0.1161
# Epoch 42/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0315 - mean_absolute_error: 0.1447 - val_loss: 0.0197 - val_mean_absolute_error: 0.1150
# Epoch 43/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0311 - mean_absolute_error: 0.1434 - val_loss: 0.0198 - val_mean_absolute_error: 0.1152
# Epoch 44/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0307 - mean_absolute_error: 0.1421 - val_loss: 0.0196 - val_mean_absolute_error: 0.1143
# Epoch 45/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0304 - mean_absolute_error: 0.1407 - val_loss: 0.0191 - val_mean_absolute_error: 0.1125
# Epoch 46/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0300 - mean_absolute_error: 0.1394 - val_loss: 0.0186 - val_mean_absolute_error: 0.1111
# Epoch 47/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0296 - mean_absolute_error: 0.1382 - val_loss: 0.0185 - val_mean_absolute_error: 0.1106
# Epoch 48/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0293 - mean_absolute_error: 0.1371 - val_loss: 0.0189 - val_mean_absolute_error: 0.1115
# Epoch 49/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0290 - mean_absolute_error: 0.1360 - val_loss: 0.0189 - val_mean_absolute_error: 0.1114
# Epoch 50/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0287 - mean_absolute_error: 0.1349 - val_loss: 0.0184 - val_mean_absolute_error: 0.1100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0184 - mean_absolute_error: 0.1100

# %%
multi_window.plot(linear)
plt.show()

# %% [markdown]
# ### CNN

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 30
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

cnn_multi_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=30, label_columns=['Checkins'])

# %%
cnn_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    Dense(units=32, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_model, cnn_multi_window)

val_performance['CNN'] = cnn_model.evaluate(cnn_multi_window.val)
performance['CNN'] = cnn_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 1s 8ms/step - loss: 0.2411 - mean_absolute_error: 0.4181 - val_loss: 0.0969 - val_mean_absolute_error: 0.3026
# Epoch 2/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0545 - mean_absolute_error: 0.1928 - val_loss: 0.0263 - val_mean_absolute_error: 0.1454
# Epoch 3/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0371 - mean_absolute_error: 0.1571 - val_loss: 0.0167 - val_mean_absolute_error: 0.1078
# Epoch 4/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0272 - mean_absolute_error: 0.1270 - val_loss: 0.0108 - val_mean_absolute_error: 0.0817
# Epoch 5/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0226 - mean_absolute_error: 0.1078 - val_loss: 0.0117 - val_mean_absolute_error: 0.0828
# Epoch 6/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0208 - mean_absolute_error: 0.1003 - val_loss: 0.0131 - val_mean_absolute_error: 0.0866
# Epoch 7/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0202 - mean_absolute_error: 0.0979 - val_loss: 0.0139 - val_mean_absolute_error: 0.0891
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0139 - mean_absolute_error: 0.0891

# %%
cnn_multi_window.plot(cnn_model)

plt.show()

# %% [markdown]
# The first plot seems to capture the trend that checkins increase as the month progresses

# %% [markdown]
# ### CNN + LSTM
#
# Combined Convolutional Neural Network and Long Short Term Memory.  The CNN part interprets the subseqeunces into a sequence which is then interpreted by the LSTM model.

# %%
cnn_lstm_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_lstm_model, cnn_multi_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 4s 30ms/step - loss: 0.2166 - mean_absolute_error: 0.3895 - val_loss: 0.0327 - val_mean_absolute_error: 0.1201
# Epoch 2/50
# 33/33 [==============================] - 1s 15ms/step - loss: 0.0809 - mean_absolute_error: 0.2409 - val_loss: 0.0391 - val_mean_absolute_error: 0.1632
# Epoch 3/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0591 - mean_absolute_error: 0.2030 - val_loss: 0.0310 - val_mean_absolute_error: 0.1394
# Epoch 4/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0327 - mean_absolute_error: 0.1350 - val_loss: 0.0208 - val_mean_absolute_error: 0.1094
# Epoch 5/50
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0277 - mean_absolute_error: 0.1195 - val_loss: 0.0165 - val_mean_absolute_error: 0.0970
# Epoch 6/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0248 - mean_absolute_error: 0.1099 - val_loss: 0.0170 - val_mean_absolute_error: 0.0995
# Epoch 7/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0238 - mean_absolute_error: 0.1070 - val_loss: 0.0157 - val_mean_absolute_error: 0.0964
# Epoch 8/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0228 - mean_absolute_error: 0.1044 - val_loss: 0.0154 - val_mean_absolute_error: 0.0959
# Epoch 9/50
# 33/33 [==============================] - 1s 21ms/step - loss: 0.0224 - mean_absolute_error: 0.1037 - val_loss: 0.0124 - val_mean_absolute_error: 0.0860
# Epoch 10/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0221 - mean_absolute_error: 0.1024 - val_loss: 0.0134 - val_mean_absolute_error: 0.0917
# Epoch 11/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0218 - mean_absolute_error: 0.1023 - val_loss: 0.0128 - val_mean_absolute_error: 0.0883
# Epoch 12/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0212 - mean_absolute_error: 0.0999 - val_loss: 0.0128 - val_mean_absolute_error: 0.0891
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0128 - mean_absolute_error: 0.0891

# %%
cnn_multi_window.plot(cnn_lstm_model)

plt.show()

# %% [markdown]
# ## Analysis
#
# Here we can compare all the different models by their mean valye score for the validation and test sets.

# %%
mae_val = [v[1] for v in val_performance.values()]
mae_test = [v[1] for v in performance.values()]

x = np.arange(len(performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.005, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.50)
plt.xticks(ticks=x, labels=performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.show()

# %% [markdown]
# We see that the CNN and linear models have the lowest MSE values while the Baseline models have much higher MSE values.
