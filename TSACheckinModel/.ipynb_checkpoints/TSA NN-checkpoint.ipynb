# %% [markdown]
# # Imports

# %%
from datetime import datetime

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
print(tf.__version__)
# Out:
# 2.9.1

# %% [markdown]
# # Feature Engineering

# %%
#read in the data
df = pd.read_csv('TSACheckinTS.csv')
df.head(5)
# Out:
#    Unnamed: 0        Date  Checkins
# 0          99  2019-01-01   2202111
# 1          98  2019-01-02   2150571
# 2          97  2019-01-03   1975947
# 3          96  2019-01-04   2229391
# 4          95  2019-01-05   2044043

# %% [markdown]
# Fast Fourier Transform

# %%
fft = tf.signal.rfft(df['Checkins'])
f_per_dataset = np.arange(0,len(fft))

n_sample = len(df['Checkins'])
weeks_per_dataset = n_sample / 7
f_per_week = f_per_dataset / weeks_per_dataset

plt.step(f_per_week, np.abs(fft))
plt.xscale('log')
plt.xticks([1, 7], ['1/week', '1/day'])
plt.xlabel('Frequency')
plt.tight_layout()
plt.show()

# %%
df.Date.describe()
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# /var/folders/wz/44mfxs_n0fs5bcb4z1rph6dm0000gn/T/ipykernel_33660/1102791421.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.Date.describe()

# %%
#create the trignonometric values for the data
timestamp_s = df.Date.map(datetime.timestamp)

day = 24 * 60 * 60

df['day_sin'] = (np.sin(timestamp_s * (2*np.pi/day))).values
df['day_cos'] = (np.cos(timestamp_s * (2*np.pi/day))).values

df.head()
# Out:
#    Unnamed: 0       Date  Checkins   day_sin   day_cos
# 0          99 2019-01-01   2202111  0.965926  0.258819
# 1          98 2019-01-02   2150571  0.965926  0.258819
# 2          97 2019-01-03   1975947  0.965926  0.258819
# 3          96 2019-01-04   2229391  0.965926  0.258819
# 4          95 2019-01-05   2044043  0.965926  0.258819

# %% [markdown]
# # Splitting data

# %%
df = df.drop(['Date'], axis=1)
df.head()
# Out:
#    Unnamed: 0  Checkins   day_sin   day_cos
# 0          99   2202111  0.965926  0.258819
# 1          98   2150571  0.965926  0.258819
# 2          97   1975947  0.965926  0.258819
# 3          96   2229391  0.965926  0.258819
# 4          95   2044043  0.965926  0.258819

# %%
n = len(df)

# Split 70:20:10 (train:validation:test)
train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):int(n*0.9)]
test_df = df[int(n*0.9):]

train_df.shape, val_df.shape, test_df.shape
# Out:
# ((1089, 4), (311, 4), (156, 4))

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1089 entries, 0 to 1088
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1089 non-null   int64
#  1   Checkins    1089 non-null   int64
#  2   day_sin     1089 non-null   float64
#  3   day_cos     1089 non-null   float64
# dtypes: float64(2), int64(2)
# memory usage: 34.2 KB

# %%
scaler = MinMaxScaler()
scaler.fit(train_df)

train_df[train_df.columns] = scaler.transform(train_df[train_df.columns])
val_df[val_df.columns] = scaler.transform(val_df[val_df.columns])
test_df[test_df.columns] = scaler.transform(test_df[test_df.columns])
# Out:
# /var/folders/wz/44mfxs_n0fs5bcb4z1rph6dm0000gn/T/ipykernel_33660/1038120894.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[train_df.columns] = scaler.transform(train_df[train_df.columns])
# /var/folders/wz/44mfxs_n0fs5bcb4z1rph6dm0000gn/T/ipykernel_33660/1038120894.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df[val_df.columns] = scaler.transform(val_df[val_df.columns])
# /var/folders/wz/44mfxs_n0fs5bcb4z1rph6dm0000gn/T/ipykernel_33660/1038120894.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[test_df.columns] = scaler.transform(test_df[test_df.columns])

# %% [markdown]
# # Deep Learning Models

# %% [markdown]
# ## `DataWindow` class

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        self.train_df = train_df 
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
        
    def split_to_input_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                        [labels[:,:,self.column_indices[name]] for name in self.label_columns], axis=-1
                    )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        return inputs, labels

    def plot(self, model=None, plot_col='Checkins', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3,1,n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                    label='Inputs', marker = '.', zorder=-10)
            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (D)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype = np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(data=data,
                                                                 targets=None,
                                                                 sequence_length=self.total_window_size,
                                                                 sequence_stride=1,
                                                                 shuffle=True,
                                                                 batch_size=32,
                                                                 )
        ds = ds.map(self.split_to_input_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## Baseline Models

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['Checkins'])

# %% [markdown]
# ### Repeat last value

# %%
class MultiStepLastBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return tf.tile(inputs[:, -1:, :], [1, 24, 1])
        return tf.tile(inputs[:, -1:, self.label_index:], [1, 24, 1])

# %%
baseline_last = MultiStepLastBaseline(label_index = column_indices['Checkins'])
baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance = {}
performance = {}

val_performance['Baseline - Last'] = baseline_last.evaluate(multi_window.val)
performance['Baseline - Last'] = baseline_last.evaluate(multi_window.test, verbose = 0)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2105 - mean_absolute_error: 0.3596

# %%
multi_window.plot(baseline_last)
plt.show()

# %% [markdown]
# ### Repeat Last Day

# %%
class RepeatBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        return inputs[:, :, self.label_index:]

# %%
baseline_repeat = RepeatBaseline(label_index=column_indices['Checkins'])

baseline_repeat.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.val)
performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.test, verbose=0)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2107 - mean_absolute_error: 0.3585

# %%
multi_window.plot(baseline_repeat)
plt.show()

# %% [markdown]
# With the repeat last day we can see that there is almost a monthly seasonality with checkins.  This is most noticeable with the third plot above.

# %% [markdown]
# ### Linear Model

# %%
label_index = column_indices['Checkins']
num_features = train_df.shape[1]

linear = Sequential([Dense(1, kernel_initializer=tf.initializers.zeros)])

history = compile_and_fit(linear, multi_window)

val_performance['Linear'] = linear.evaluate(multi_window.val)
performance['Linear'] = linear.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 1s 8ms/step - loss: 0.3096 - mean_absolute_error: 0.4877 - val_loss: 0.3992 - val_mean_absolute_error: 0.6268
# Epoch 2/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2226 - mean_absolute_error: 0.4040 - val_loss: 0.2877 - val_mean_absolute_error: 0.5308
# Epoch 3/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1601 - mean_absolute_error: 0.3378 - val_loss: 0.2049 - val_mean_absolute_error: 0.4462
# Epoch 4/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1176 - mean_absolute_error: 0.2918 - val_loss: 0.1465 - val_mean_absolute_error: 0.3750
# Epoch 5/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0901 - mean_absolute_error: 0.2615 - val_loss: 0.1057 - val_mean_absolute_error: 0.3160
# Epoch 6/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0732 - mean_absolute_error: 0.2394 - val_loss: 0.0776 - val_mean_absolute_error: 0.2677
# Epoch 7/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0632 - mean_absolute_error: 0.2232 - val_loss: 0.0597 - val_mean_absolute_error: 0.2320
# Epoch 8/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0575 - mean_absolute_error: 0.2120 - val_loss: 0.0476 - val_mean_absolute_error: 0.2046
# Epoch 9/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0543 - mean_absolute_error: 0.2042 - val_loss: 0.0397 - val_mean_absolute_error: 0.1844
# Epoch 10/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0522 - mean_absolute_error: 0.1989 - val_loss: 0.0352 - val_mean_absolute_error: 0.1719
# Epoch 11/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0508 - mean_absolute_error: 0.1950 - val_loss: 0.0316 - val_mean_absolute_error: 0.1615
# Epoch 12/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0497 - mean_absolute_error: 0.1919 - val_loss: 0.0295 - val_mean_absolute_error: 0.1550
# Epoch 13/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0487 - mean_absolute_error: 0.1892 - val_loss: 0.0281 - val_mean_absolute_error: 0.1508
# Epoch 14/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0478 - mean_absolute_error: 0.1870 - val_loss: 0.0268 - val_mean_absolute_error: 0.1467
# Epoch 15/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0468 - mean_absolute_error: 0.1849 - val_loss: 0.0265 - val_mean_absolute_error: 0.1459
# Epoch 16/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0459 - mean_absolute_error: 0.1826 - val_loss: 0.0254 - val_mean_absolute_error: 0.1424
# Epoch 17/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0450 - mean_absolute_error: 0.1807 - val_loss: 0.0252 - val_mean_absolute_error: 0.1417
# Epoch 18/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0441 - mean_absolute_error: 0.1785 - val_loss: 0.0244 - val_mean_absolute_error: 0.1392
# Epoch 19/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0431 - mean_absolute_error: 0.1764 - val_loss: 0.0240 - val_mean_absolute_error: 0.1380
# Epoch 20/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0422 - mean_absolute_error: 0.1746 - val_loss: 0.0238 - val_mean_absolute_error: 0.1372
# Epoch 21/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0413 - mean_absolute_error: 0.1724 - val_loss: 0.0230 - val_mean_absolute_error: 0.1344
# Epoch 22/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0404 - mean_absolute_error: 0.1702 - val_loss: 0.0224 - val_mean_absolute_error: 0.1325
# Epoch 23/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0396 - mean_absolute_error: 0.1682 - val_loss: 0.0221 - val_mean_absolute_error: 0.1311
# Epoch 24/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0387 - mean_absolute_error: 0.1663 - val_loss: 0.0217 - val_mean_absolute_error: 0.1301
# Epoch 25/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0378 - mean_absolute_error: 0.1640 - val_loss: 0.0213 - val_mean_absolute_error: 0.1283
# Epoch 26/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0370 - mean_absolute_error: 0.1621 - val_loss: 0.0210 - val_mean_absolute_error: 0.1271
# Epoch 27/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0362 - mean_absolute_error: 0.1599 - val_loss: 0.0202 - val_mean_absolute_error: 0.1242
# Epoch 28/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0354 - mean_absolute_error: 0.1577 - val_loss: 0.0199 - val_mean_absolute_error: 0.1227
# Epoch 29/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0346 - mean_absolute_error: 0.1557 - val_loss: 0.0194 - val_mean_absolute_error: 0.1210
# Epoch 30/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0338 - mean_absolute_error: 0.1537 - val_loss: 0.0191 - val_mean_absolute_error: 0.1198
# Epoch 31/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0331 - mean_absolute_error: 0.1517 - val_loss: 0.0186 - val_mean_absolute_error: 0.1176
# Epoch 32/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0324 - mean_absolute_error: 0.1498 - val_loss: 0.0182 - val_mean_absolute_error: 0.1159
# Epoch 33/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0317 - mean_absolute_error: 0.1480 - val_loss: 0.0182 - val_mean_absolute_error: 0.1158
# Epoch 34/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0310 - mean_absolute_error: 0.1461 - val_loss: 0.0179 - val_mean_absolute_error: 0.1142
# Epoch 35/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0303 - mean_absolute_error: 0.1438 - val_loss: 0.0170 - val_mean_absolute_error: 0.1108
# Epoch 36/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0296 - mean_absolute_error: 0.1420 - val_loss: 0.0169 - val_mean_absolute_error: 0.1101
# Epoch 37/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0290 - mean_absolute_error: 0.1402 - val_loss: 0.0166 - val_mean_absolute_error: 0.1087
# Epoch 38/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0284 - mean_absolute_error: 0.1384 - val_loss: 0.0163 - val_mean_absolute_error: 0.1075
# Epoch 39/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0278 - mean_absolute_error: 0.1366 - val_loss: 0.0160 - val_mean_absolute_error: 0.1059
# Epoch 40/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0273 - mean_absolute_error: 0.1347 - val_loss: 0.0154 - val_mean_absolute_error: 0.1030
# Epoch 41/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0267 - mean_absolute_error: 0.1330 - val_loss: 0.0153 - val_mean_absolute_error: 0.1026
# Epoch 42/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0262 - mean_absolute_error: 0.1314 - val_loss: 0.0152 - val_mean_absolute_error: 0.1018
# Epoch 43/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0257 - mean_absolute_error: 0.1296 - val_loss: 0.0149 - val_mean_absolute_error: 0.1004
# Epoch 44/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0253 - mean_absolute_error: 0.1280 - val_loss: 0.0147 - val_mean_absolute_error: 0.0996
# Epoch 45/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0248 - mean_absolute_error: 0.1264 - val_loss: 0.0144 - val_mean_absolute_error: 0.0978
# Epoch 46/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0244 - mean_absolute_error: 0.1248 - val_loss: 0.0142 - val_mean_absolute_error: 0.0971
# Epoch 47/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0240 - mean_absolute_error: 0.1233 - val_loss: 0.0141 - val_mean_absolute_error: 0.0961
# Epoch 48/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0236 - mean_absolute_error: 0.1218 - val_loss: 0.0136 - val_mean_absolute_error: 0.0939
# Epoch 49/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0232 - mean_absolute_error: 0.1204 - val_loss: 0.0138 - val_mean_absolute_error: 0.0946
# Epoch 50/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0228 - mean_absolute_error: 0.1190 - val_loss: 0.0134 - val_mean_absolute_error: 0.0929
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0134 - mean_absolute_error: 0.0929

# %%
multi_window.plot(linear)
plt.show()

# %% [markdown]
# ### CNN

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 30
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

cnn_multi_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=30, label_columns=['Checkins'])

# %%
cnn_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    Dense(units=32, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_model, cnn_multi_window)

val_performance['CNN'] = cnn_model.evaluate(cnn_multi_window.val)
performance['CNN'] = cnn_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 1s 9ms/step - loss: 0.2547 - mean_absolute_error: 0.4328 - val_loss: 0.1114 - val_mean_absolute_error: 0.3260
# Epoch 2/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0568 - mean_absolute_error: 0.1975 - val_loss: 0.0321 - val_mean_absolute_error: 0.1650
# Epoch 3/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0412 - mean_absolute_error: 0.1688 - val_loss: 0.0157 - val_mean_absolute_error: 0.1067
# Epoch 4/50
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0318 - mean_absolute_error: 0.1428 - val_loss: 0.0117 - val_mean_absolute_error: 0.0882
# Epoch 5/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0250 - mean_absolute_error: 0.1198 - val_loss: 0.0112 - val_mean_absolute_error: 0.0842
# Epoch 6/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0217 - mean_absolute_error: 0.1044 - val_loss: 0.0099 - val_mean_absolute_error: 0.0768
# Epoch 7/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0204 - mean_absolute_error: 0.0985 - val_loss: 0.0114 - val_mean_absolute_error: 0.0818
# Epoch 8/50
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0198 - mean_absolute_error: 0.0963 - val_loss: 0.0106 - val_mean_absolute_error: 0.0789
# Epoch 9/50
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0194 - mean_absolute_error: 0.0951 - val_loss: 0.0120 - val_mean_absolute_error: 0.0830
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0120 - mean_absolute_error: 0.0830

# %%
cnn_multi_window.plot(cnn_model)

plt.show()

# %% [markdown]
# The first plot seems to capture the trend that checkins increase as the month progresses

# %% [markdown]
# ### CNN + LSTM
#
# Combined Convolutional Neural Network and Long Short Term Memory.  The CNN part interprets the subseqeunces into a sequence which is then interpreted by the LSTM model.

# %%
cnn_lstm_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_lstm_model, cnn_multi_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 4s 32ms/step - loss: 0.2051 - mean_absolute_error: 0.3749 - val_loss: 0.0360 - val_mean_absolute_error: 0.1310
# Epoch 2/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0823 - mean_absolute_error: 0.2427 - val_loss: 0.0609 - val_mean_absolute_error: 0.2229
# Epoch 3/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0654 - mean_absolute_error: 0.2154 - val_loss: 0.0371 - val_mean_absolute_error: 0.1602
# Epoch 4/50
# 33/33 [==============================] - 1s 15ms/step - loss: 0.0390 - mean_absolute_error: 0.1502 - val_loss: 0.0294 - val_mean_absolute_error: 0.1217
# Epoch 5/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0317 - mean_absolute_error: 0.1264 - val_loss: 0.0138 - val_mean_absolute_error: 0.0857
# Epoch 6/50
# 33/33 [==============================] - 1s 15ms/step - loss: 0.0273 - mean_absolute_error: 0.1176 - val_loss: 0.0209 - val_mean_absolute_error: 0.1066
# Epoch 7/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0242 - mean_absolute_error: 0.1104 - val_loss: 0.0204 - val_mean_absolute_error: 0.1080
# Epoch 8/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0225 - mean_absolute_error: 0.1053 - val_loss: 0.0175 - val_mean_absolute_error: 0.0996
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0175 - mean_absolute_error: 0.0996

# %%
cnn_multi_window.plot(cnn_lstm_model)

plt.show()
