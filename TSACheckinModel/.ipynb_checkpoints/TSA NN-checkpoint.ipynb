# %% [markdown]
# # Imports

# %%
from datetime import datetime

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
print(tf.__version__)
# Out:
# 2.9.1

# %% [markdown]
# # Feature Engineering

# %%
#read in the data
df = pd.read_csv('TSACheckinTS.csv')
df.head(5)
# Out:
#    Unnamed: 0        Date  Checkins
# 0          99  2019-01-01   2202111
# 1          98  2019-01-02   2150571
# 2          97  2019-01-03   1975947
# 3          96  2019-01-04   2229391
# 4          95  2019-01-05   2044043

# %% [markdown]
# ### Fast Fourier Transform

# %%
df.Date.describe()
df['Date'] = pd.to_datetime(df['Date'])

# %%
#create the trignonometric values for the data
timestamp_s = df.Date.map(pd.Timestamp.timestamp)

day = 24 * 60 * 60
month = 30*day
year = (365.25)*day

#daily frequencies
df['day_sin'] = (np.sin(timestamp_s * (2*np.pi/day))).values
df['day_cos'] = (np.cos(timestamp_s * (2*np.pi/day))).values
#monthly frequencies
df['month_sin'] = (np.sin(timestamp_s * (2*np.pi/month))).values
df['month_cos'] = (np.cos(timestamp_s * (2*np.pi/month))).values
#yearly frequencies
df['year_sin'] = (np.sin(timestamp_s * (2*np.pi/year))).values
df['year_cos'] = (np.cos(timestamp_s * (2*np.pi/year))).values

df.head()
# Out:
#    Unnamed: 0       Date  Checkins       day_sin  day_cos  month_sin  \
# 0          99 2019-01-01   2202111 -5.030095e-12      1.0  -0.406737
# 1          98 2019-01-02   2150571 -7.315560e-13      1.0  -0.587785
# 2          97 2019-01-03   1975947 -1.098493e-11      1.0  -0.743145
# 3          96 2019-01-04   2229391 -6.686394e-12      1.0  -0.866025
# 4          95 2019-01-05   2044043 -2.387855e-12      1.0  -0.951057
#
#    month_cos  year_sin  year_cos
# 0  -0.913545 -0.004301  0.999991
# 1  -0.809017  0.012901  0.999917
# 2  -0.669131  0.030100  0.999547
# 3  -0.500000  0.047289  0.998881
# 4  -0.309017  0.064464  0.997920

# %%
fft = tf.signal.rfft(df['Checkins'])
f_per_dataset = np.arange(0, len(fft))

n_samples_d = len(df['Checkins'])
days_per_year = 365.25
years_per_dataset = n_samples_d/(days_per_year)
months_per_year = 12
months_per_dataset = years_per_dataset/months_per_year

f_per_year = f_per_dataset/years_per_dataset
plt.step(f_per_year, np.abs(fft))
plt.xscale('log')
#plt.ylim(0, 400000)
plt.xlim([0.1, max(plt.xlim())])
plt.xticks([1, 12, 365.2524], labels=['1/Year', '1/month','1/day'])
_ = plt.xlabel('Frequency (log scale)')
# Out:
# 2023-04-22 16:52:14.749534: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Splitting data

# %%
df = df.drop(['Date'], axis=1)
df.head()
# Out:
#    Unnamed: 0  Checkins       day_sin  day_cos  month_sin  month_cos  \
# 0          99   2202111 -5.030095e-12      1.0  -0.406737  -0.913545
# 1          98   2150571 -7.315560e-13      1.0  -0.587785  -0.809017
# 2          97   1975947 -1.098493e-11      1.0  -0.743145  -0.669131
# 3          96   2229391 -6.686394e-12      1.0  -0.866025  -0.500000
# 4          95   2044043 -2.387855e-12      1.0  -0.951057  -0.309017
#
#    year_sin  year_cos
# 0 -0.004301  0.999991
# 1  0.012901  0.999917
# 2  0.030100  0.999547
# 3  0.047289  0.998881
# 4  0.064464  0.997920

# %%
n = len(df)

# Split 70:20:10 (train:validation:test)
train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):int(n*0.9)]
test_df = df[int(n*0.9):]

train_df.shape, val_df.shape, test_df.shape
# Out:
# ((1089, 8), (311, 8), (156, 8))

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1089 entries, 0 to 1088
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1089 non-null   int64
#  1   Checkins    1089 non-null   int64
#  2   day_sin     1089 non-null   float64
#  3   day_cos     1089 non-null   float64
#  4   month_sin   1089 non-null   float64
#  5   month_cos   1089 non-null   float64
#  6   year_sin    1089 non-null   float64
#  7   year_cos    1089 non-null   float64
# dtypes: float64(6), int64(2)
# memory usage: 68.2 KB

# %%
scaler = MinMaxScaler()
scaler.fit(train_df)

train_df[train_df.columns] = scaler.transform(train_df[train_df.columns])
val_df[val_df.columns] = scaler.transform(val_df[val_df.columns])
test_df[test_df.columns] = scaler.transform(test_df[test_df.columns])

# %% [markdown]
# # Deep Learning Models

# %% [markdown]
# ## `DataWindow` class

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        #stores raw data
        self.train_df = train_df 
        self.val_df = val_df
        self.test_df = test_df
        #work out label column indices
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        #work out window parameters
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
        
    def split_to_input_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                        [labels[:,:,self.column_indices[name]] for name in self.label_columns], axis=-1
                    )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        return inputs, labels

    def plot(self, model=None, plot_col='Checkins', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(max_n,1,n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                    label='Inputs', marker = '.', zorder=-10)
            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (D)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype = np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(data=data,
                                                                 targets=None,
                                                                 sequence_length=self.total_window_size,
                                                                 sequence_stride=1,
                                                                 shuffle=True,
                                                                 batch_size=32,
                                                                 )
        ds = ds.map(self.split_to_input_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## Baseline Models

# %%
multi_window = DataWindow(input_width=30, label_width=30, shift=1, label_columns=['Checkins'])

# %% [markdown]
# ### Repeat last value

# %%
class MultiStepLastBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return tf.tile(inputs[:, -1:, :], [1, 30, 1])
        return tf.tile(inputs[:, -1:, self.label_index:], [1, 30, 1])

# %%
baseline_last = MultiStepLastBaseline(label_index = column_indices['Checkins'])
baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance = {}
performance = {}

val_performance['Baseline - Last'] = baseline_last.evaluate(multi_window.val)
performance['Baseline - Last'] = baseline_last.evaluate(multi_window.test, verbose = 0)
# Out:
# 9/9 [==============================] - 1s 2ms/step - loss: 0.2153 - mean_absolute_error: 0.3790

# %%
multi_window.plot(baseline_last)
plt.show()

# %% [markdown]
# ### Repeat Last Day

# %%
class RepeatBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        return inputs[:, :, self.label_index:]

# %%
baseline_repeat = RepeatBaseline(label_index=column_indices['Checkins'])

baseline_repeat.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.val)
performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.test, verbose=0)
# Out:
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2140 - mean_absolute_error: 0.3770

# %%
multi_window.plot(baseline_repeat)
plt.show()

# %% [markdown]
# With the repeat last day we can see that there is almost a monthly seasonality with checkins.  This is most noticeable with the third plot above.

# %% [markdown]
# ### Linear Model

# %%
label_index = column_indices['Checkins']
num_features = train_df.shape[1]

linear = Sequential([Dense(1, kernel_initializer=tf.initializers.zeros)])

history = compile_and_fit(linear, multi_window)

val_performance['Linear'] = linear.evaluate(multi_window.val)
performance['Linear'] = linear.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 34/34 [==============================] - 1s 7ms/step - loss: 0.2889 - mean_absolute_error: 0.4685 - val_loss: 0.3256 - val_mean_absolute_error: 0.5595
# Epoch 2/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.1760 - mean_absolute_error: 0.3537 - val_loss: 0.1986 - val_mean_absolute_error: 0.4292
# Epoch 3/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.1134 - mean_absolute_error: 0.2852 - val_loss: 0.1240 - val_mean_absolute_error: 0.3303
# Epoch 4/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0836 - mean_absolute_error: 0.2505 - val_loss: 0.0829 - val_mean_absolute_error: 0.2625
# Epoch 5/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0708 - mean_absolute_error: 0.2324 - val_loss: 0.0626 - val_mean_absolute_error: 0.2228
# Epoch 6/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0655 - mean_absolute_error: 0.2225 - val_loss: 0.0515 - val_mean_absolute_error: 0.1986
# Epoch 7/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0629 - mean_absolute_error: 0.2170 - val_loss: 0.0465 - val_mean_absolute_error: 0.1870
# Epoch 8/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0609 - mean_absolute_error: 0.2131 - val_loss: 0.0440 - val_mean_absolute_error: 0.1817
# Epoch 9/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0590 - mean_absolute_error: 0.2097 - val_loss: 0.0430 - val_mean_absolute_error: 0.1800
# Epoch 10/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0570 - mean_absolute_error: 0.2062 - val_loss: 0.0412 - val_mean_absolute_error: 0.1762
# Epoch 11/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0551 - mean_absolute_error: 0.2025 - val_loss: 0.0391 - val_mean_absolute_error: 0.1715
# Epoch 12/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0531 - mean_absolute_error: 0.1987 - val_loss: 0.0370 - val_mean_absolute_error: 0.1664
# Epoch 13/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0512 - mean_absolute_error: 0.1951 - val_loss: 0.0353 - val_mean_absolute_error: 0.1626
# Epoch 14/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0493 - mean_absolute_error: 0.1914 - val_loss: 0.0336 - val_mean_absolute_error: 0.1585
# Epoch 15/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0475 - mean_absolute_error: 0.1878 - val_loss: 0.0324 - val_mean_absolute_error: 0.1558
# Epoch 16/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0456 - mean_absolute_error: 0.1839 - val_loss: 0.0304 - val_mean_absolute_error: 0.1504
# Epoch 17/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0438 - mean_absolute_error: 0.1804 - val_loss: 0.0299 - val_mean_absolute_error: 0.1496
# Epoch 18/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0420 - mean_absolute_error: 0.1771 - val_loss: 0.0290 - val_mean_absolute_error: 0.1475
# Epoch 19/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0403 - mean_absolute_error: 0.1735 - val_loss: 0.0278 - val_mean_absolute_error: 0.1443
# Epoch 20/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0387 - mean_absolute_error: 0.1697 - val_loss: 0.0258 - val_mean_absolute_error: 0.1386
# Epoch 21/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0371 - mean_absolute_error: 0.1662 - val_loss: 0.0251 - val_mean_absolute_error: 0.1368
# Epoch 22/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0355 - mean_absolute_error: 0.1626 - val_loss: 0.0238 - val_mean_absolute_error: 0.1331
# Epoch 23/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0340 - mean_absolute_error: 0.1591 - val_loss: 0.0231 - val_mean_absolute_error: 0.1312
# Epoch 24/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0326 - mean_absolute_error: 0.1560 - val_loss: 0.0231 - val_mean_absolute_error: 0.1315
# Epoch 25/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0312 - mean_absolute_error: 0.1528 - val_loss: 0.0219 - val_mean_absolute_error: 0.1276
# Epoch 26/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0299 - mean_absolute_error: 0.1495 - val_loss: 0.0206 - val_mean_absolute_error: 0.1235
# Epoch 27/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0286 - mean_absolute_error: 0.1464 - val_loss: 0.0196 - val_mean_absolute_error: 0.1203
# Epoch 28/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0275 - mean_absolute_error: 0.1433 - val_loss: 0.0190 - val_mean_absolute_error: 0.1182
# Epoch 29/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0262 - mean_absolute_error: 0.1405 - val_loss: 0.0191 - val_mean_absolute_error: 0.1186
# Epoch 30/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0251 - mean_absolute_error: 0.1375 - val_loss: 0.0177 - val_mean_absolute_error: 0.1141
# Epoch 31/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0241 - mean_absolute_error: 0.1347 - val_loss: 0.0171 - val_mean_absolute_error: 0.1119
# Epoch 32/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0231 - mean_absolute_error: 0.1319 - val_loss: 0.0163 - val_mean_absolute_error: 0.1093
# Epoch 33/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0221 - mean_absolute_error: 0.1292 - val_loss: 0.0159 - val_mean_absolute_error: 0.1080
# Epoch 34/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0212 - mean_absolute_error: 0.1265 - val_loss: 0.0153 - val_mean_absolute_error: 0.1061
# Epoch 35/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0204 - mean_absolute_error: 0.1241 - val_loss: 0.0150 - val_mean_absolute_error: 0.1051
# Epoch 36/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0196 - mean_absolute_error: 0.1216 - val_loss: 0.0145 - val_mean_absolute_error: 0.1030
# Epoch 37/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0188 - mean_absolute_error: 0.1191 - val_loss: 0.0134 - val_mean_absolute_error: 0.0989
# Epoch 38/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0181 - mean_absolute_error: 0.1168 - val_loss: 0.0131 - val_mean_absolute_error: 0.0977
# Epoch 39/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0174 - mean_absolute_error: 0.1146 - val_loss: 0.0130 - val_mean_absolute_error: 0.0975
# Epoch 40/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0168 - mean_absolute_error: 0.1124 - val_loss: 0.0125 - val_mean_absolute_error: 0.0953
# Epoch 41/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0161 - mean_absolute_error: 0.1104 - val_loss: 0.0119 - val_mean_absolute_error: 0.0928
# Epoch 42/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0156 - mean_absolute_error: 0.1084 - val_loss: 0.0118 - val_mean_absolute_error: 0.0926
# Epoch 43/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0150 - mean_absolute_error: 0.1065 - val_loss: 0.0114 - val_mean_absolute_error: 0.0908
# Epoch 44/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0145 - mean_absolute_error: 0.1045 - val_loss: 0.0112 - val_mean_absolute_error: 0.0901
# Epoch 45/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0140 - mean_absolute_error: 0.1026 - val_loss: 0.0112 - val_mean_absolute_error: 0.0900
# Epoch 46/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0135 - mean_absolute_error: 0.1010 - val_loss: 0.0107 - val_mean_absolute_error: 0.0878
# Epoch 47/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0992 - val_loss: 0.0106 - val_mean_absolute_error: 0.0875
# Epoch 48/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0976 - val_loss: 0.0102 - val_mean_absolute_error: 0.0862
# Epoch 49/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0124 - mean_absolute_error: 0.0962 - val_loss: 0.0100 - val_mean_absolute_error: 0.0853
# Epoch 50/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0120 - mean_absolute_error: 0.0948 - val_loss: 0.0099 - val_mean_absolute_error: 0.0850
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0099 - mean_absolute_error: 0.0850

# %%
multi_window.plot(linear)
plt.show()

# %% [markdown]
# ### CNN

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 30
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

cnn_multi_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=1, label_columns=['Checkins'])

# %%
cnn_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    Dense(units=32, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_model, cnn_multi_window)

val_performance['CNN'] = cnn_model.evaluate(cnn_multi_window.val)
performance['CNN'] = cnn_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 34/34 [==============================] - 1s 9ms/step - loss: 0.2508 - mean_absolute_error: 0.4269 - val_loss: 0.0708 - val_mean_absolute_error: 0.2407
# Epoch 2/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0674 - mean_absolute_error: 0.2154 - val_loss: 0.0304 - val_mean_absolute_error: 0.1536
# Epoch 3/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0348 - mean_absolute_error: 0.1584 - val_loss: 0.0138 - val_mean_absolute_error: 0.0986
# Epoch 4/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0150 - mean_absolute_error: 0.1025 - val_loss: 0.0072 - val_mean_absolute_error: 0.0703
# Epoch 5/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0077 - mean_absolute_error: 0.0718 - val_loss: 0.0064 - val_mean_absolute_error: 0.0682
# Epoch 6/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0658 - val_loss: 0.0062 - val_mean_absolute_error: 0.0675
# Epoch 7/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0645 - val_loss: 0.0061 - val_mean_absolute_error: 0.0664
# Epoch 8/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0062 - mean_absolute_error: 0.0634 - val_loss: 0.0059 - val_mean_absolute_error: 0.0660
# Epoch 9/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_absolute_error: 0.0626 - val_loss: 0.0058 - val_mean_absolute_error: 0.0654
# Epoch 10/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_absolute_error: 0.0617 - val_loss: 0.0057 - val_mean_absolute_error: 0.0647
# Epoch 11/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_absolute_error: 0.0608 - val_loss: 0.0056 - val_mean_absolute_error: 0.0641
# Epoch 12/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0056 - mean_absolute_error: 0.0601 - val_loss: 0.0054 - val_mean_absolute_error: 0.0636
# Epoch 13/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_absolute_error: 0.0593 - val_loss: 0.0054 - val_mean_absolute_error: 0.0627
# Epoch 14/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0054 - mean_absolute_error: 0.0585 - val_loss: 0.0052 - val_mean_absolute_error: 0.0625
# Epoch 15/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0053 - mean_absolute_error: 0.0580 - val_loss: 0.0052 - val_mean_absolute_error: 0.0626
# Epoch 16/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_absolute_error: 0.0574 - val_loss: 0.0051 - val_mean_absolute_error: 0.0613
# Epoch 17/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_absolute_error: 0.0567 - val_loss: 0.0050 - val_mean_absolute_error: 0.0606
# Epoch 18/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0050 - mean_absolute_error: 0.0563 - val_loss: 0.0049 - val_mean_absolute_error: 0.0606
# Epoch 19/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0049 - mean_absolute_error: 0.0557 - val_loss: 0.0049 - val_mean_absolute_error: 0.0597
# Epoch 20/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_absolute_error: 0.0553 - val_loss: 0.0048 - val_mean_absolute_error: 0.0590
# Epoch 21/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0047 - mean_absolute_error: 0.0549 - val_loss: 0.0048 - val_mean_absolute_error: 0.0587
# Epoch 22/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_absolute_error: 0.0545 - val_loss: 0.0047 - val_mean_absolute_error: 0.0593
# Epoch 23/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0046 - mean_absolute_error: 0.0542 - val_loss: 0.0046 - val_mean_absolute_error: 0.0589
# Epoch 24/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0046 - mean_absolute_error: 0.0539 - val_loss: 0.0046 - val_mean_absolute_error: 0.0580
# Epoch 25/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_absolute_error: 0.0537 - val_loss: 0.0046 - val_mean_absolute_error: 0.0593
# Epoch 26/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0045 - mean_absolute_error: 0.0533 - val_loss: 0.0046 - val_mean_absolute_error: 0.0590
# Epoch 27/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0045 - mean_absolute_error: 0.0533 - val_loss: 0.0045 - val_mean_absolute_error: 0.0581
# Epoch 28/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0045 - mean_absolute_error: 0.0530 - val_loss: 0.0045 - val_mean_absolute_error: 0.0575
# Epoch 29/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0528 - val_loss: 0.0047 - val_mean_absolute_error: 0.0562
# Epoch 30/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0044 - mean_absolute_error: 0.0526 - val_loss: 0.0045 - val_mean_absolute_error: 0.0568
# Epoch 31/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_absolute_error: 0.0524 - val_loss: 0.0045 - val_mean_absolute_error: 0.0574
# Epoch 32/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_absolute_error: 0.0523 - val_loss: 0.0045 - val_mean_absolute_error: 0.0582
# Epoch 33/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0523 - val_loss: 0.0045 - val_mean_absolute_error: 0.0566
# Epoch 34/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0044 - mean_absolute_error: 0.0522 - val_loss: 0.0046 - val_mean_absolute_error: 0.0587
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0587

# %%
cnn_multi_window.plot(cnn_model)

plt.show()

# %% [markdown]
# The first plot seems to capture the trend that checkins increase as the month progresses

# %% [markdown]
# ### CNN + LSTM
#
# Combined Convolutional Neural Network and Long Short Term Memory.  The CNN part interprets the subseqeunces into a sequence which is then interpreted by the LSTM model.

# %%
cnn_lstm_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_lstm_model, cnn_multi_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 34/34 [==============================] - 3s 29ms/step - loss: 0.2047 - mean_absolute_error: 0.3773 - val_loss: 0.0327 - val_mean_absolute_error: 0.1303
# Epoch 2/50
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0799 - mean_absolute_error: 0.2387 - val_loss: 0.0471 - val_mean_absolute_error: 0.1893
# Epoch 3/50
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0630 - mean_absolute_error: 0.2149 - val_loss: 0.0375 - val_mean_absolute_error: 0.1672
# Epoch 4/50
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0277 - mean_absolute_error: 0.1337 - val_loss: 0.0132 - val_mean_absolute_error: 0.0849
# Epoch 5/50
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0104 - mean_absolute_error: 0.0785 - val_loss: 0.0090 - val_mean_absolute_error: 0.0720
# Epoch 6/50
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0084 - mean_absolute_error: 0.0711 - val_loss: 0.0078 - val_mean_absolute_error: 0.0702
# Epoch 7/50
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0075 - mean_absolute_error: 0.0679 - val_loss: 0.0071 - val_mean_absolute_error: 0.0685
# Epoch 8/50
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0069 - mean_absolute_error: 0.0662 - val_loss: 0.0069 - val_mean_absolute_error: 0.0683
# Epoch 9/50
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0066 - mean_absolute_error: 0.0648 - val_loss: 0.0065 - val_mean_absolute_error: 0.0672
# Epoch 10/50
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0063 - mean_absolute_error: 0.0637 - val_loss: 0.0063 - val_mean_absolute_error: 0.0666
# Epoch 11/50
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0061 - mean_absolute_error: 0.0629 - val_loss: 0.0061 - val_mean_absolute_error: 0.0655
# Epoch 12/50
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0059 - mean_absolute_error: 0.0621 - val_loss: 0.0062 - val_mean_absolute_error: 0.0662
# Epoch 13/50
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0058 - mean_absolute_error: 0.0613 - val_loss: 0.0060 - val_mean_absolute_error: 0.0656
# Epoch 14/50
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0057 - mean_absolute_error: 0.0609 - val_loss: 0.0059 - val_mean_absolute_error: 0.0645
# Epoch 15/50
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0056 - mean_absolute_error: 0.0603 - val_loss: 0.0059 - val_mean_absolute_error: 0.0654
# Epoch 16/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0056 - mean_absolute_error: 0.0604 - val_loss: 0.0060 - val_mean_absolute_error: 0.0652
# Epoch 17/50
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0055 - mean_absolute_error: 0.0599 - val_loss: 0.0062 - val_mean_absolute_error: 0.0665
# Epoch 18/50
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0055 - mean_absolute_error: 0.0602 - val_loss: 0.0060 - val_mean_absolute_error: 0.0648
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0060 - mean_absolute_error: 0.0648

# %%
cnn_multi_window.plot(cnn_lstm_model)

plt.show()

# %% [markdown]
# ## Analysis
#
# Here we can compare all the different models by their mean value score for the validation and test sets.

# %%
mae_val = [v[1] for v in val_performance.values()]
mae_test = [v[1] for v in performance.values()]

x = np.arange(len(performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.005, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.50)
plt.xticks(ticks=x, labels=performance.keys())
plt.legend(loc='best')
plt.tight_layout()
plt.title('Comparison of MSE values')

plt.show()

# %% [markdown]
# We see that the CNN and linear models have the lowest MSE values while the Baseline models have much higher MSE values.
